# %%
import pandas as pd
import numpy as np

# Sample data for other dataframes

statuses = pd.read_csv('status.csv')
departments = pd.read_csv('departments.csv')
advisors = pd.read_csv('advisors.csv')
researchers = pd.read_csv('researchers.csv')
sponsors = pd.read_csv('sponsors.csv')
projects = pd.read_csv('random_titles.csv')


# Function to randomly select rows from dataframes
def randomly_select(df, n):
    return df.sample(n=n, replace=True).reset_index(drop=True)

# Number of rows for the final dataset
n_rows = 10

# Create the final dataset
final_data = pd.DataFrame({
    'title': randomly_select(projects, n_rows)['title'],
    'biography': randomly_select(projects, n_rows)['biography'],
    'status': randomly_select(statuses, n_rows)['status_name'],
    'department_name': randomly_select(departments, n_rows)['department_name'],
    'advisors': randomly_select(advisors, n_rows)['first_name'],
    'researchers': randomly_select(researchers, n_rows)['name'],
    'sponsors': randomly_select(sponsors, n_rows)['name'],
})

print(final_data)
final_data.to_csv('projects.csv', index=False)
# Out:
#                             title  \
# 0           Data Science Analysis
# 1                  AI Development
# 2                     AI Analysis
# 3            Robotics Advancement
# 4                  AI Development
# 5      Quantum Computing Analysis
# 6      Quantum Computing Analysis
# 7  Quantum Computing Optimization
# 8       Cybersecurity Advancement
# 9                  AI Advancement
#
#                                            biography       status  \
# 0  Aimed at revolutionizing Cybersecurity with a ...    Completed
# 1  Exploring the potential of Cybersecurity with ...    Completed
# 2  Exploring the potential of Cybersecurity with ...    Completed
# 3  Exploring the potential of Robotics with a foc...      Pending
# 4  Pioneering breakthroughs in AI with a focus on...  In Progress
# 5  Aimed at revolutionizing Robotics with a focus...  In Progress
# 6  Pioneering breakthroughs in Bioinformatics wit...  In Progress
# 7  A comprehensive study on AI with a focus on so...    Completed
# 8  This project focuses on Cybersecurity with a f...  In Progress
# 9  A comprehensive study on AI with a focus on so...      Pending
#
#     department_name advisors        researchers  \
# 0              Math  Charlie      John Hopfield
# 1           Biology  Charlie   Abhijit Banerjee
# 2  Computer Science      Bob       Barack Obama
# 3  Computer Science  Charlie  Riccardo Giacconi
# 4              Math  Charlie      Denis Mukwege
# 5  Computer Science  Charlie       Richard Axel
# 6  Computer Science    Alice             Mo Yan
# 7           Biology  Charlie       Angus Deaton
# 8           Biology    Alice       Jimmy Carter
# 9           Biology      Bob   William Nordhaus
#
#                           sponsors
# 0                              IBM
# 1  New York Life Insurance Company
# 2                   Morgan Stanley
# 3                      Wells Fargo
# 4                        Microsoft
# 5                         Alphabet
# 6                    Goldman Sachs
# 7                      Merck & Co.
# 8                    Goldman Sachs
# 9                Johnson & Johnson
